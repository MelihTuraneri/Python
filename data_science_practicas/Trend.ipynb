# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import seaborn as sns
from pickle import NONE
# %pip install pymongo[srv]
from pymongo import MongoClient
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 269 kB 5.1 MB/s
# ...

# %%
client = MongoClient("mongodb+srv://melihturaneri:hE1ofvjkmlTeKSVr@sposasondisprezzata.b0n0wrw.mongodb.net/?retryWrites=true&w=majority")
trend_url = "https://www.trendyol.com/sr?wc=103108&attr=467%7C899121_23012%2C249%7C3379_3376&pi="

# %%
def model_kirpici(baslik,marka,islemci):
  baslik = baslik.upper()
  marka = marka.upper()
  islemci = islemci.upper()
  uzunluk = len(marka)
  # if(marka == "APPLE"):
  #   islemci = islemci.replace("APPLE ","")

  print(baslik[uzunluk + 1: baslik.find(islemci) - 1])

  # if (baslik.find(islemci) == -1):
  #   model_listesi.append(baslik[uzunluk + 1: baslik.find(islemci_no) - 3])
  # else:  
  #   ##print(baslik)
  #   ##print("marka : {}, marka_sirasi {}, islemci : {}, islemci_sirasi : {}".format(marka,baslik.find(marka) + uzunluk,islemci,baslik.find(islemci)))
  #   model_listesi.append(baslik[uzunluk + 1: baslik.find(islemci) - 1])

# %%
hdd_listesi= []
ssd_listesi= []
baslik_listesi = []
fiyat_listesi = []
marka_listesi = []
ekran_listesi = []
ram_listesi = []
os_listesi = []
islemci_listesi = []
trend_liste = []
link_listesi = []
foto_liste = []
for i in range(12):
  url = trend_url+str(i+1)
  r = requests.get(url)
  soup = BeautifulSoup(r.content,"lxml")
  urunler = soup.find_all("div",attrs={"class":"p-card-chldrn-cntnr card-border"})

  for urun in urunler:
    marka_listesi.append(urun.span.get("title"))
    urunLink = "https://www.trendyol.com"+urun.a.get("href")
    link_listesi.append(urunLink)
    urun_r = requests.get(urunLink)
    urun_soup = BeautifulSoup(urun_r.content,"lxml")

    if urun_soup.find("h1", attrs={"class":"pr-new-br"}) != None:
        baslik_listesi.append(urun_soup.find("h1", attrs={"class":"pr-new-br"}).text)
    else:
        baslik_listesi.append(None)

    if urun_soup.find("span",attrs={"class":"prc-dsc"}) == None:
      fiyat_listesi.append(None)
    else:
      fiyat_listesi.append(urun_soup.find("span",attrs={"class":"prc-dsc"}).text.replace(" TL",""))

    if urun_soup.find("div", attrs={"class":"flex-container"}) != None:
      foto_liste.append(urun_soup.find("div", attrs={"class":"flex-container"}).img.get("src"))
    else:
      foto_liste.append(None) 

    ozellikler = urun_soup.find_all("li",attrs={"class":"detail-attr-item"})
    for ozellik in ozellikler:
     ## print(ozellik.find("span").text)
     ## print(ozellik.find("b").text)
      
      if (ozellik.find("span").text) == "Ekran Boyutu":
        ekran_listesi.append(ozellik.find("b").text)
        trend_liste.append("Trendyol")

      elif (ozellik.find("span").text) == "İşletim Sistemi":
        os_listesi.append(ozellik.find("b").text.replace(" ",""))

      elif (ozellik.find("span").text) == "Ram (Sistem Belleği)":
        ram_listesi.append(ozellik.find("b").text)

      elif (ozellik.find("span").text) == "İşletim Sistemi":
        os_listesi.append(ozellik.find("b").text.replace(" ",""))

      elif (ozellik.find("span").text) == "İşlemci Tipi":
        islemci1 = ozellik.find("b").text

      elif (ozellik.find("span").text) == "İşlemci Modeli":
        islemci_listesi.append(islemci1 + " " + ozellik.find("b").text)
        ##model_kirpici(urun_soup.find("h1",attrs={"itemprop":"name"}).text.strip(),marka,islemci1,ozellik.find("td").text.strip())

      if (ozellik.find("span").text) == "SSD Kapasitesi":
        if (ozellik.find("b").text == "Yok" or ozellik.find("b").text == "SSD Yok"): 
         df["ssd"][counter] = ssd_listesi.append("NULL")
        else:
          ssd_listesi.append(ozellik.find("b").text) 
        
      if (ozellik.find("span").text) == "Hard Disk Kapasitesi":
        if (ozellik.find("b").text == "Yok" or ozellik.find("b").text == "HDD Yok"): 
         hdd_listesi.append("NULL")
        else:
          hdd_listesi.append(ozellik.find("b").text)

# %%
sasi = "os_listesi {},islemci_listesi {},ram_listesi {},ekran_listesi {},marka_listesi {},fiyat_listesi {},hdd_listesi {},ssd_listesi {},trend_liste {},link_listesi {},foto_liste {},baslik_listesi {}"

sasi.format(len(os_listesi),len(islemci_listesi),len(ram_listesi),len(ekran_listesi),len(marka_listesi),len(fiyat_listesi),len(hdd_listesi),len(ssd_listesi),len(trend_liste),len(link_listesi),len(foto_liste),len(baslik_listesi))
# Out:
# 'os_listesi 163,islemci_listesi 163,ram_listesi 163,ekran_listesi 163,marka_listesi 216,fiyat_listesi 216,hdd_listesi 163,ssd_listesi 163,trend_liste 163,link_listesi 216,foto_liste 216,baslik_listesi 216'

# %%
df2.drop([2], axis=0, inplace=True)

# %%
marka_listesi = df2["Marka"]
fiyat_listesi = df2["Fiyat"]
link_listesi = df2["Link"]
foto_liste = df2["Foto"]
baslik_listesi = df2["Baslik"]

# %%
dict2 = {'Marka': marka_listesi,'Fiyat': fiyat_listesi,'Link': link_listesi,'Foto': foto_liste,'Baslik': baslik_listesi}
df2 = pd.DataFrame(dict2)
df2.head(50)

# %%
df.dtypes
# Out:
# Marka              object
# Baslik             object
# Isletim Sistemi    object
# Islemci            object
# Bellek             object
# Ekran Boyutu       object
# Fiyat              object
# HDD                object
# SSD                object
# Site               object
# Link               object
# Foto               object
# dtype: object

# %%
dict = {'Marka': marka_listesi, 'Baslik': baslik_listesi, 'Isletim Sistemi': os_listesi, 'Islemci': islemci_listesi,'Bellek': ram_listesi, 'Ekran Boyutu': ekran_listesi,'Fiyat': fiyat_listesi, 'HDD': hdd_listesi, 'SSD': ssd_listesi, 'Fiyat': fiyat_listesi, 'Site': trend_liste,'Link': link_listesi,'Foto': foto_liste}
df = pd.DataFrame(dict)
df = df.drop_duplicates()
df.reset_index(drop = True,inplace = True)
df.tail(50)

# %%
dfC["Fiyat"] = gercek_fiyat

# %%
liste = dfC["Fiyat"]

# %%
gercek_fiyat = []
for i in range(len(liste)):
  flt = float(liste[i])
  gercek_fiyat.append(flt)

gercek_fiyat

# %%
for i in range(len(liste)):
  liste[i] = liste[i][:-3]

# %%
dfC = df.copy()

# %%
db = client.ColabDB
personCollection = db.person

# %%
it = df["Marka"].count()

for i in range(5):
  dictM = {"doc":{"Marka":df["Marka"][i],
                  "Isletim Sistemi":df["Isletim Sistemi"][i],
                  "Islemci":df["Islemci"][i],
                  "Bellek":df["Bellek"][i],
                  "Disk" : {
                      "HDD":df["HDD"][i],
                      "SSD":df["SSD"][i]
                  },
                  "Ekran Boyutu":df["Ekran Boyutu"][i],
                  "Fiyat":df["Fiyat"][i],
                  "Site":df["Site"][i]}
          }
  for b in dictM.values():
    personCollection.insert_one(b)

# %%
dfC.to_csv('trend.csv', encoding = 'utf-8-sig') 
files.download('trend.csv')

# %%
dfC["Marka"].value_counts()
# Out:
# Lenovo    148
# Asus       20
# Dell       16
# HP         16
# Acer        7
# Apple       4
# Huawei      2
# Msi         1
# sorbi       1
# Chuwi       1
# Name: Marka, dtype: int64

# %%
dfC["Link"][1]
# Out:
# 'https://www.trendyol.com/lenovo/ideapad-3-82h80146tx-intel-core-i5-1135g7-8gb-256gb-ssd-1tb-hard-disk-2gb-mx350-15-6-fullhd-p-263591325?boutiqueId=615107&merchantId=514546'

# %%
for i in range(len(dfC["Marka"])):
  if dfC["Marka"][i] == "LENOVO":
    dfC["Marka"][i] = "Lenovo"
  elif dfC["Marka"][i] == "ASUS":
    dfC["Marka"][i] = "Asus"
  elif dfC["Marka"][i] == "ACER":
    dfC["Marka"][i] = "Acer"
  elif dfC["Marka"][i] == "MSI":
    dfC["Marka"][i] = "Msi"

# %%
dfC[:50]
# Out:
#      Marka                                             Baslik Isletim Sistemi  \
# 0   Huawei  Huawei Matebook D15 AMD Ryzen 5 5500U 8GB 512G...         Windows
# 1   Lenovo  LENOVO Ideapad 3 82h80146tx Intel Core I5-1135...         FreeDos
# 2   Lenovo  LENOVO V14 82kc000qtx08 Ryzen3 5300u 12gb 1tb+...         FreeDos
# 3   Lenovo  LENOVO Ideapad Gaming 3 82k100cltx i7-11370h 1...         FreeDos
# 4   Lenovo  LENOVO Ideapad Intel Core I5-1135g7 8gb/512gb ...         Windows
# 5   Lenovo  LENOVO Ideapad Gaming 3 82k200k4tx Ryzen5 5600...         FreeDos
# 6     Dell  Dell Vostro 3400 I3-1115g4 4gb 1TB+256GB Ssd 1...         Windows
# 7     Asus  ASUS X415EA-EK977W / i5-11135G7 / 8GB / 256GB ...       Windows11
# 8   Lenovo  LENOVO Ideapad Gaming 3 Amd Ryzen 5 5600h 16gb...         FreeDos
# 9   Lenovo  LENOVO V14 G2 Alc Amd Ryzen 5 5500u 8gb 512gb ...         FreeDos
# 10    Asus  ASUS Intel Core i5 11300H 16GB RAM 512GB SSD 4...         FreeDos
# ...
