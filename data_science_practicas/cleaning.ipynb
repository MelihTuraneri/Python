# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import json

# %%
with open("t20_wc_match_results.json") as f:
   data = json.load(f)
df_results = pd.DataFrame(data[0]["matchSummary"])

# %%
with open("t20_wc_player_info.json") as f:
   data = json.load(f)
df_player = pd.DataFrame(data)

# %%
with open("t20_wc_batting_summary.json") as f:
   data = json.load(f)
all_matches = []
for match in data:
    all_matches.extend(match["battingSummary"])
df_batting = pd.DataFrame(all_matches)

# %%
with open("t20_wc_bowling_summary.json") as f:
   data = json.load(f)
all_matches = []
for match in data:
    all_matches.extend(match["bowlingSummary"])
df_bowling = pd.DataFrame(all_matches)

# %%
df_results.to_csv("results.csv", index=False)
df_player.to_csv("player.csv", index=False)
df_batting.to_csv("battling.csv", index=False)
df_bowling.to_csv("bowling.csv", index=False)

# %% [markdown]
# ### **Result DataFrame**

# %%
df_results.head()
# Out:
#          team1        team2       winner     margin   ground     matchDate  \
# 0      Namibia    Sri Lanka      Namibia    55 runs  Geelong  Oct 16, 2022
# 1  Netherlands       U.A.E.  Netherlands  3 wickets  Geelong  Oct 16, 2022
# 2     Scotland  West Indies     Scotland    42 runs   Hobart  Oct 17, 2022
# 3      Ireland     Zimbabwe     Zimbabwe    31 runs   Hobart  Oct 17, 2022
# 4      Namibia  Netherlands  Netherlands  5 wickets  Geelong  Oct 18, 2022
#
#      scorecard
# 0  T20I # 1823
# 1  T20I # 1825
# 2  T20I # 1826
# 3  T20I # 1828
# 4  T20I # 1830

# %%
df_results.rename({"scorecard" : "match_id"}, axis=1, inplace=True)

# %%
df_results["matchDate"] = df_results["matchDate"].apply(lambda x: x.replace("Oct", "10,") if x.find("Oct") != -1 else x.replace("Nov", "11,"))

# %%
df_results["stage"] = df_results["matchDate"].apply(lambda x: "Qualifier" if x < "10, 22, 2022"  else "Super 12")

# %%
df_results.head()
# Out:
#          team1        team2       winner     margin   ground     matchDate  \
# 0      Namibia    Sri Lanka      Namibia    55 runs  Geelong  10, 16, 2022
# 1  Netherlands       U.A.E.  Netherlands  3 wickets  Geelong  10, 16, 2022
# 2     Scotland  West Indies     Scotland    42 runs   Hobart  10, 17, 2022
# 3      Ireland     Zimbabwe     Zimbabwe    31 runs   Hobart  10, 17, 2022
# 4      Namibia  Netherlands  Netherlands  5 wickets  Geelong  10, 18, 2022
#
#       match_id      stage
# 0  T20I # 1823  Qualifier
# 1  T20I # 1825  Qualifier
# 2  T20I # 1826  Qualifier
# 3  T20I # 1828  Qualifier
# 4  T20I # 1830  Qualifier

# %%
match_ids_dict = {}
for index,row in df_results.iterrows():
    key1 = row["team1"] + " Vs " + row["team2"]
    key2 = row["team2"] + " Vs " + row["team1"]
    
    match_ids_dict[key1] = row["match_id"]
    match_ids_dict[key2] = row["match_id"]

# %% [markdown]
# ### **Batting DataFrame**

# %%
df_batting.head()
# Out:
#                   match teamInnings  battingPos             batsmanName  \
# 0  Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1  Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2  Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3  Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4  Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)
#
#                          dismissal runs balls 4s 6s      SR
# 0     c Pramod Madushan b Chameera    3     6  0  0   50.00
# 1      c Shanaka b Pramod Madushan    9     9  1  0  100.00
# 2          c †Mendis b Karunaratne   20    12  1  2  166.66
# 3  c DM de Silva b Pramod Madushan   26    24  2  0  108.33
# 4     c Gunathilaka b PWH de Silva   20    24  0  0   83.33

# %%
df_batting["out/not_out"] = df_batting["dismissal"].apply(lambda x: "out" if len(x) > 0 else "not_out")
df_batting.drop("dismissal", axis = 1, inplace=True)
df_batting["batsmanName"] = df_batting["batsmanName"].str.replace(r"[^a-zA-Z ()]+", " ").str.strip()
# Out:
# /tmp/ipykernel_8034/3335097893.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_batting["batsmanName"] = df_batting["batsmanName"].str.replace(r"[^a-zA-Z ()]+", " ").str.strip()

# %%
df_batting.head(5)
# Out:
#                   match teamInnings  battingPos             batsmanName runs  \
# 0  Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen    3
# 1  Namibia Vs Sri Lanka     Namibia           2           Divan la Cock    9
# 2  Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie Eaton   20
# 3  Namibia Vs Sri Lanka     Namibia           4           Stephan Baard   26
# 4  Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)   20
#
#   balls 4s 6s      SR out/not_out
# 0     6  0  0   50.00         out
# 1     9  1  0  100.00         out
# 2    12  1  2  166.66         out
# 3    24  2  0  108.33         out
# 4    24  0  0   83.33         out

# %%
df_batting["match_id"] = df_batting["match"].map(match_ids_dict)
# Out:
#                   match teamInnings  battingPos             batsmanName runs  \
# 0  Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen    3
# 1  Namibia Vs Sri Lanka     Namibia           2           Divan la Cock    9
# 2  Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie Eaton   20
# 3  Namibia Vs Sri Lanka     Namibia           4           Stephan Baard   26
# 4  Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)   20
#
#   balls 4s 6s      SR out/not_out     match_id
# 0     6  0  0   50.00         out  T20I # 1823
# 1     9  1  0  100.00         out  T20I # 1823
# 2    12  1  2  166.66         out  T20I # 1823
# 3    24  2  0  108.33         out  T20I # 1823
# 4    24  0  0   83.33         out  T20I # 1823

# %%
df_batting["batsmanName"] = df_batting["batsmanName"].apply(lambda x: x[:x.find("(c)")] if x.find("(c)") != - 1 else x)

# %%
df_batting["out/not_out"] = df_batting["out/not_out"].apply(lambda x: 1 if x == "out" else 0)

# %%
df_batting.rename({"teamInnings" : "team", "4s" : "fours", "6s" : "sixes", "out/not_out" : "out"}, axis=1, inplace=True)

# %%
df_batting.head()
# Out:
#                   match     team  battingPos             batsmanName runs  \
# 0  Namibia Vs Sri Lanka  Namibia           1      Michael van Lingen    3
# 1  Namibia Vs Sri Lanka  Namibia           2           Divan la Cock    9
# 2  Namibia Vs Sri Lanka  Namibia           3  Jan Nicol Loftie Eaton   20
# 3  Namibia Vs Sri Lanka  Namibia           4           Stephan Baard   26
# 4  Namibia Vs Sri Lanka  Namibia           5         Gerhard Erasmus   20
#
#   balls fours sixes      SR  out     match_id
# 0     6     0     0   50.00    1  T20I # 1823
# 1     9     1     0  100.00    1  T20I # 1823
# 2    12     1     2  166.66    1  T20I # 1823
# 3    24     2     0  108.33    1  T20I # 1823
# 4    24     0     0   83.33    1  T20I # 1823

# %% [markdown]
# ### **Bowling DataFrame**

# %%
df_bowling.head()
# Out:
#                   match bowlingTeam                  bowlerName overs maiden  \
# 0  Namibia Vs Sri Lanka   Sri Lanka          Maheesh Theekshana     4      0
# 1  Namibia Vs Sri Lanka   Sri Lanka         Dushmantha Chameera     4      0
# 2  Namibia Vs Sri Lanka   Sri Lanka             Pramod Madushan     4      0
# 3  Namibia Vs Sri Lanka   Sri Lanka         Chamika Karunaratne     4      0
# 4  Namibia Vs Sri Lanka   Sri Lanka  Wanindu Hasaranga de Silva     4      0
#
#   runs wickets economy 0s 4s 6s wides noBalls
# 0   23       1    5.75  7  0  0     2       0
# 1   39       1    9.75  6  3  1     2       0
# 2   37       2    9.25  6  3  1     0       0
# 3   36       1    9.00  7  3  1     1       0
# 4   27       1    6.75  8  1  1     0       0

# %%
df_bowling.rename({"bowlingTeam" : "team", "0s" : "zeros", "4s" : "fours", "6s" : "sixes", "out/not_out" : "out"}, axis=1, inplace=True)

# %%
df_bowling[["overs1", "overs2"]] = df_bowling['overs'].str.split('.', expand=True)
df_bowling.drop("overs", axis = 1, inplace=True)
df_bowling["overs2"].fillna(0, inplace=True)
df_bowling = df_bowling.iloc[:, [0,1,2,12,13,3,4,5,6,7,8,9,10,11]]

# %%
df_bowling["overs1"] = df_bowling["overs1"].astype("int")
df_bowling["overs2"] = df_bowling["overs2"].astype("int")

# %%
df_bowling["ball"] = df_bowling["overs1"]*6 + df_bowling["overs2"]

# %%
df_bowling.head()
# Out:
#                   match       team                  bowlerName  overs1  \
# 0  Namibia Vs Sri Lanka  Sri Lanka          Maheesh Theekshana       4
# 1  Namibia Vs Sri Lanka  Sri Lanka         Dushmantha Chameera       4
# 2  Namibia Vs Sri Lanka  Sri Lanka             Pramod Madushan       4
# 3  Namibia Vs Sri Lanka  Sri Lanka         Chamika Karunaratne       4
# 4  Namibia Vs Sri Lanka  Sri Lanka  Wanindu Hasaranga de Silva       4
#
#    overs2 maiden runs wickets economy zeros fours sixes wides noBalls  ball
# 0       0      0   23       1    5.75     7     0     0     2       0    24
# 1       0      0   39       1    9.75     6     3     1     2       0    24
# 2       0      0   37       2    9.25     6     3     1     0       0    24
# 3       0      0   36       1    9.00     7     3     1     1       0    24
# 4       0      0   27       1    6.75     8     1     1     0       0    24

# %% [markdown]
# ### **Player DataFrame**

# %%
df_player.head()
# Out:
#                      name     team    battingStyle  \
# 0      Michael van Lingen  Namibia   Left hand Bat
# 1           Divan la Cock  Namibia  Right hand Bat
# 2  Jan Nicol Loftie-Eaton  Namibia   Left hand Bat
# 3           Stephan Baard  Namibia  Right hand Bat
# 4      Gerhard Erasmus(c)  Namibia  Right hand Bat
#
#                  bowlingStyle         playingRole description
# 0             Left arm Medium  Bowling Allrounder
# 1                    Legbreak      Opening Batter
# 2  Right arm Medium, Legbreak              Batter
# 3       Right arm Medium fast              Batter
# 4          Right arm Offbreak          Allrounder

# %%
df_player["name"] = df_player["name"].apply(lambda x: x[:x.find("(c)")] if x.find("(c)") != - 1 else x)

# %%
df_player.head()
# Out:
#                      name     team    battingStyle  \
# 0      Michael van Lingen  Namibia   Left hand Bat
# 1           Divan la Cock  Namibia  Right hand Bat
# 2  Jan Nicol Loftie-Eaton  Namibia   Left hand Bat
# 3           Stephan Baard  Namibia  Right hand Bat
# 4         Gerhard Erasmus  Namibia  Right hand Bat
#
#                  bowlingStyle         playingRole description
# 0             Left arm Medium  Bowling Allrounder
# 1                    Legbreak      Opening Batter
# 2  Right arm Medium, Legbreak              Batter
# 3       Right arm Medium fast              Batter
# 4          Right arm Offbreak          Allrounder
