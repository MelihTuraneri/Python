# %%
import pandas as pd
import numpy as np
import math

# %%
df = pd.read_csv('country_vaccination_stats.csv')
df.head()
# Out:
#      country        date  daily_vaccinations   vaccines
# 0  Argentina  12/29/2020                 NaN  Sputnik V
# 1  Argentina  12/30/2020             15656.0  Sputnik V
# 2  Argentina  12/31/2020             15656.0  Sputnik V
# 3  Argentina    1/1/2021             11070.0  Sputnik V
# 4  Argentina    1/2/2021              8776.0  Sputnik V

# %%
df["daily_vaccinations"].isnull().value_counts()
# Out:
# False    1442
# True       60
# Name: daily_vaccinations, dtype: int64

# %%
null_index_list = df[df['daily_vaccinations'].isnull()].index.tolist() # getting indexes that have null data

# %%
for i in null_index_list:
    if math.isnan(df[df['country'] == df['country'][i]].sort_values("daily_vaccinations").iloc[0].values[2]):
        df['daily_vaccinations'][i] = 0
    else:
        df['daily_vaccinations'][i] = df[df['country'] == df['country'][i]].sort_values("daily_vaccinations").iloc[0].values[2]
# Out:
# /tmp/ipykernel_16133/100181220.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['daily_vaccinations'][i] = df[df['country'] == df['country'][i]].sort_values("daily_vaccinations").iloc[0].values[2]
# /tmp/ipykernel_16133/100181220.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['daily_vaccinations'][i] = 0

# %%
df["daily_vaccinations"].isnull().value_counts()
# Out:
# False    1502
# Name: daily_vaccinations, dtype: int64

# %%
df.loc[null_index_list] # showing null indexes are now not null
# Out:
#                    country        date  daily_vaccinations  \
# 0                Argentina  12/29/2020              6483.0
# 28                 Austria    1/5/2021              3368.0
# 48                 Bahrain  12/23/2020               943.0
# 77                 Belgium  12/28/2020                 1.0
# 103                 Brazil   1/16/2021               112.0
# 113               Bulgaria  12/29/2020               472.0
# 141                 Canada  12/14/2020               866.0
# 184                  Chile  12/24/2020                51.0
# 217                  China  12/15/2020            187500.0
# 254             Costa Rica  12/24/2020               240.0
# 280                Croatia  12/30/2020               989.0
# 307                 Cyprus    1/6/2021               534.0
# 324                Czechia  12/27/2020              1822.0
# 354                Denmark  12/27/2020              1994.0
# 384                Ecuador   1/21/2021               108.0
# ...

# %%
df.to_csv('country_vaccination_stats_imputed.csv')
